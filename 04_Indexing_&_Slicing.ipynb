# %%
import numpy as np
marks = np.array([70,80,65,90,75])
print(marks.dtype)
print(marks.ndim)
print(marks.shape)
print(marks.size)
# Out:
# int64
# 1
# (5,)
# 5

# %%
marks[0]
# Out:
# np.int64(70)

# %%
marks[3]
# Out:
# np.int64(90)

# %%
marks[2]
# Out:
# np.int64(65)

# %%
marks
# Out:
# array([70, 80, 65, 90, 75])

# %%
# print all the numpy array sepreated by a space.
print(marks, end=" ")
# Out:
# [70 80 65 90 75]

# %%
n = len(marks)
for i in range(n):
  print(marks[i],end = " ")
# Out:
# 70 80 65 90 75

# %%
n= len(marks)
print(marks[n-1])
# Out:
# 75

# %%
print(marks[-1])
# Out:
# 75

# %%
print(marks[n-2])
# Out:
# 90

# %%
print(marks[-2])
# Out:
# 90

# %%
print(marks)
# Out:
# [70 80 65 90 75]

# %%
marks[2]=marks[2]+5

# %%
print(marks)
# Out:
# [70 80 70 90 75]

# %%
marks = marks+5

# %%
print(marks)
# Out:
# [75 85 75 95 80]

# %%
arr = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])
print(arr)
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]
# 2
# (3, 3)
# 9
# int64

# %%
print(arr[0][2])
# Out:
# 30

# %%
arr[0,2]
# Out:
# np.int64(30)

# %%
print(arr[0,2])
# Out:
# 30

# %%
print(arr[1,1])
# Out:
# 50

# %%
print(arr)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
# Print all the digonal elements of the 2nd np array.
np.diagonal(arr)
# Out:
# array([10, 50, 90])

# %%
# A college stores marks of 4 students in 3 subjects: Maths, Science, and English

# import numpy as np

# marks = np.array([
#  [72,85,90],
#  [65,78,82],
#  [88,91,84],
#  [70,76,80]
# ])

# Perform the following:

# Display the marks of the third student.
# Display the Science marks of the second student.
# Add 5 bonus marks to every student's English marks.
# Change the Maths marks of the fourth student to 75.
# Display the final marks array.

# %%
marks = np.array([
  [72,85,90],
  [65,78,82],
  [88,91,84],
  [70,76,80]
 ])

# %%
# Display the marks of the third student.
print(marks[2])
# Out:
# [88 91 84]

# %%
# Display the Science marks of the second student.
print(marks[1,1])
# Out:
# 78

# %%
# Add 5 bonus marks to every student's English marks.
marks[:,2] = marks[:,2]+5

# %%
marks
# Out:
# array([[72, 85, 95],
#        [65, 78, 87],
#        [88, 91, 89],
#        [70, 76, 85]])

# %%
# Change the Maths marks of the fourth student to 75.
marks[3,0]=75

# %%
print(marks)
# Out:
# [[72 85 95]
#  [65 78 87]
#  [88 91 89]
#  [75 76 85]]

# %%
# Display the final marks array.
print(marks)
# Out:
# [[72 85 95]
#  [65 78 87]
#  [88 91 89]
#  [75 76 85]]

# %%
# A company records monthly sales for 3 branches. The columns represent January, February, and March.

# import numpy as np

# sales = np.array([
#     [120,150,180],
#     [100,130,160],
#     [200, 220, 250]
# ])

# Perform the following:

# Display the complete sales data of Branch 2.
# Display the sales of all branches in February.
# Increase the March sales of every branch by 10%.
# The January sales of Branch 1 were entered incorrectly. Change them from 120 to 135.
# Display the updated sales array.

# %%
sales = np.array([
     [120,150,180],
     [100,130,160],
     [200, 220, 250]
 ])

# %%
# Display the complete sales data of Branch 2.
print(sales[1])
# Out:
# [100 130 160]

# %%
# Display the sales of all branches in February.
print(sales[:,1])
# Out:
# [150 130 220]

# %%
# Increase the March sales of every branch by 10%.
sales[:,2] = 1.1* (sales[:,2])

# %%
print(sales)
# Out:
# [[120 150 198]
#  [100 130 176]
#  [200 220 275]]

# %%
# The January sales of Branch 1 were entered incorrectly. Change them from 120 to 135.
sales[0,0] = 135

# %%
print(sales)
# Out:
# [[135 150 198]
#  [100 130 176]
#  [200 220 275]]

# %%
# Display the updated sales array.
print(sales)
# Out:
# [[135 150 198]
#  [100 130 176]
#  [200 220 275]]

# %%
# An organization stores employee information as:
# Salary | Experience
# import numpy as np
# employees = np.array([
# [30000, 2],
# [40000, 4],
# [50000, 6],
# [60000, 8]
# ])
# Perform the following:
# Display the information of the last employee using negative indexing.
# Display the salary of the second employee.
# Increase the salary of the third employee by 15%.
# Add 1 year of experience to the first employee.
# Display the final employee array.

# %%
import numpy as np
employees = np.array([
 [30000, 2],
 [40000, 4],
 [50000, 6],
 [60000, 8]
 ])

# %%
# Display the information of the last employee using negative indexing.
print(employees[-1])
# Out:
# [60000     8]

# %%
# Display the salary of the second employee.
print(employees[1,0])
# Out:
# 40000

# %%
# Increase the salary of the third employee by 15%.
employees[2,0] = 1.15*employees[2,0]

# %%
employees[2,0]*=1.15

# %%
print(employees)
# Out:
# [[30000     2]
#  [40000     4]
#  [57499     6]
#  [60000     8]]

# %%
# Add 1 year of experience to the first employee.
employees[0,1] = employees[0,1]+1

# %%
print(employees)
# Out:
# [[30000     3]
#  [40000     4]
#  [57499     6]
#  [60000     8]]

# %%
# Display the final employee array.
print(employees)
# Out:
# [[30000     3]
#  [40000     4]
#  [57499     6]
#  [60000     8]]

# %%
# A company has inventory information for 4 products across 3 warehouses.
# Columns: Warehouse A, Warehouse B, Warehouse C
# import numpy as np
# inventory = np.array([
# [100, 120, 150],
# [80, 90, 110],
# [200, 180, 160],
# [50, 70, 90]
# ])
# Perform the following:
# Display the inventory of Product 3 across all warehouses.
# Display the inventory of Warehouse B for all products.
# Warehouse A receives 20 additional units of every product. Update the array.
# The inventory of Product 4 in Warehouse C is incorrect. Change it to 100.
# Display the final inventory.

# %%
import numpy as np
inventory = np.array([
 [100, 120, 150],
 [80, 90, 110],
 [200, 180, 160],
 [50, 70, 90]
 ])

# %%
# Display the inventory of Product 3 across all warehouses.
print(inventory[2])
# Out:
# [200 180 160]

# %%
# Display the inventory of Warehouse B for all products.
print(inventory[:,1])
# Out:
# [120  90 180  70]

# %%
# Warehouse A receives 20 additional units of every product. Update the array.
inventory[:,0]+=20
print(inventory)
# Out:
# [[120 120 150]
#  [100  90 110]
#  [220 180 160]
#  [ 70  70  90]]

# %%
# The inventory of Product 4 in Warehouse C is incorrect. Change it to 100.
inventory[3,2]=100
print(inventory)
# Out:
# [[120 120 150]
#  [100  90 110]
#  [220 180 160]
#  [ 70  70 100]]

# %%
# Display the final inventory.
print(inventory)
# Out:
# [[120 120 150]
#  [100  90 110]
#  [220 180 160]
#  [ 70  70 100]]

# %%
# A weather application stores temperatures for 3 cities.
# Columns: Morning, Afternoon, Evening
# import numpy as np
# temperature = np.array([
# [24, 35, 28],
# [22, 32, 26],
# [27, 38, 30]
# ])
# Perform the following:
# Display the complete temperature data of the first city.
# Display all afternoon temperatures.
# Display the evening temperature of the last city using negative indexing.
# Increase all morning temperatures by 2°C.
# The afternoon temperature of the second city was recorded incorrectly. Change it from 32 to 34.
# Display the final temperature array.

# %%
import numpy as np
temperature = np.array([
 [24, 35, 28],
 [22, 32, 26],
 [27, 38, 30]
 ])

# %%
# Display the complete temperature data of the first city.
print(temperature[0,:])
# Out:
# [24 35 28]

# %%
# Display all afternoon temperatures.
print(temperature[:,1])
# Out:
# [35 32 38]

# %%
# Increase all morning temperatures by 2°C.
temperature[:,0] +=2
print(temperature)
# Out:
# [[26 35 28]
#  [24 32 26]
#  [29 38 30]]

# %%
# The afternoon temperature of the second city was recorded incorrectly. Change it from 32 to 34.
temperature[1,1] = 34
print(temperature)
# Out:
# [[26 35 28]
#  [24 34 26]
#  [29 38 30]]

# %%
# Display the evening temperature of the last city using negative indexing.
temperature[-1,-1]
# Out:
# np.int64(30)

# %%
temperature[-1,2]
# Out:
# np.int64(30)

# %%
# Display the final temperature array.
print(temperature)
# Out:
# [[26 35 28]
#  [24 34 26]
#  [29 38 30]]
